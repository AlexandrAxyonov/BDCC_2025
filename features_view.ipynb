# %%
import torch

# путь к твоему файлу .pt
pt_path = r"C:/Prgrm/BDCC_2025/features/wsm_depression/train/body/body__clipv-openai-clip-vit-base-patch32-frame-cls__frames30__avg-raw__pv-v1-stable/feats_seed42_subset0_avg-raw.pt"

# загружаем через PyTorch
data = torch.load(pt_path, map_location="cpu")

print("Тип верхнего объекта:", type(data))

# посмотрим header
print("\n----- HEADER -----")
if "header" in data:
    for k, v in data["header"].items():
        print(f"{k}: {v}")

# посмотрим data
print("\n----- DATA -----")
if "data" in data:
    sample_keys = list(data["data"].keys())
    print("Количество сэмплов:", len(sample_keys))
    print("Пример ключей:", sample_keys[:5])  # первые 5 ключей

    # берём первый сэмпл
    first_key = sample_keys[0]
    print("\nПервый ключ:", first_key)

    sample = data["data"][first_key]

    # показываем, что внутри (обычно mean / std)
    for stat_name, tensor in sample.items():
        if torch.is_tensor(tensor):
            print(f"{stat_name}: тензор формы {tensor.shape}")
            # первые 10 чисел для наглядности
            print("  первые значения:", tensor[:10])
        else:
            print(f"{stat_name}: {type(tensor)}")
# Out:
# Тип верхнего объекта: <class 'dict'>
#
# ----- HEADER -----
# mod: body
# extractor_fp: clipv:openai/clip-vit-base-patch32:frame-cls
# avg: raw
# frames: 30
# pre_v: v1-stable
#
# ----- DATA -----
# Количество сэмплов: 3715
# Пример ключей: ['N4Vfr3zdpGU_001', 'N4Vfr3zdpGU_002', 'N4Vfr3zdpGU_003', 'N4Vfr3zdpGU_004', 'N4Vfr3zdpGU_005']
#
# Первый ключ: N4Vfr3zdpGU_001
# seq: тензор формы torch.Size([30, 512])
#   первые значения: tensor([[-0.0117, -0.0427, -0.4296,  ...,  0.7570, -0.0169, -0.2228],
#         [ 0.0180, -0.0952, -0.3815,  ...,  0.6660, -0.2168, -0.0010],
#         [-0.1673, -0.1982, -0.0964,  ...,  0.3357, -0.1956, -0.0908],
#         ...,
#         [ 0.2172, -0.0157, -0.1982,  ...,  0.7596,  0.0673, -0.2365],
#         [-0.0071, -0.3990, -0.2839,  ...,  0.4397, -0.0142, -0.1342],
#         [-0.2288,  0.0715, -0.0844,  ...,  0.4043, -0.1819, -0.2803]])

# %%
import torch

# путь к твоему файлу .pt
pt_path = r"C:/Prgrm/BDCC_2025/features/wsm_parkinson/train/body/body__vitv-google-vit-base-patch16-224-seq__frames30__avg-raw__pv-v1-stable/feats_seed42_subset0_avg-raw.pt"

# загружаем через PyTorch
data = torch.load(pt_path, map_location="cpu")

print("Тип верхнего объекта:", type(data))

# посмотрим header
print("\n----- HEADER -----")
if "header" in data:
    for k, v in data["header"].items():
        print(f"{k}: {v}")

# посмотрим data
print("\n----- DATA -----")
if "data" in data:
    sample_keys = list(data["data"].keys())
    print("Количество сэмплов:", len(sample_keys))
    print("Пример ключей:", sample_keys[:5])  # первые 5 ключей

    # берём первый сэмпл
    first_key = sample_keys[0]
    print("\nПервый ключ:", first_key)

    sample = data["data"][first_key]

    # показываем, что внутри (обычно mean / std)
    for stat_name, tensor in sample.items():
        if torch.is_tensor(tensor):
            print(f"{stat_name}: тензор формы {tensor.shape}")
            # первые 10 чисел для наглядности
            print("  первые значения:", tensor[:10])
        else:
            print(f"{stat_name}: {type(tensor)}")
# Out:
# Тип верхнего объекта: <class 'dict'>
#
# ----- HEADER -----
# mod: body
# extractor_fp: vitv:google/vit-base-patch16-224:seq
# avg: raw
# frames: 30
# pre_v: v1-stable
#
# ----- DATA -----
# Количество сэмплов: 2736
# Пример ключей: ['FfdJwuwoqP4_001', 'FfdJwuwoqP4_002', 'FfdJwuwoqP4_003', 'FfdJwuwoqP4_004', 'FfdJwuwoqP4_005']
#
# Первый ключ: FfdJwuwoqP4_001
# seq: тензор формы torch.Size([5880, 768])
#   первые значения: tensor([[ 0.0408,  1.7517, -0.8275,  ..., -0.1795,  0.6278, -0.9204],
#         [ 0.1307,  1.4212, -1.2285,  ..., -0.0265,  0.6963, -0.6133],
#         [-0.2246,  1.3748, -1.0895,  ...,  0.0437,  0.4901, -0.9489],
#         ...,
#         [-0.1119,  0.8404, -0.0307,  ...,  0.0989, -0.0214, -1.1465],
#         [ 0.1616,  1.4419,  0.2509,  ..., -0.0337,  0.2725, -0.8895],
#         [ 0.1017,  1.3412,  0.3771,  ..., -0.6044,  0.2499, -1.2997]])

# %%
import torch

# путь к твоему файлу .pt
pt_path = r"C:/Prgrm/BDCC_2025/features/wsm_depression/train/body/body__vitv-google-vit-base-patch16-224-frame-cls__frames30__avg-raw__pv-v1-stable/feats_seed42_subset10_avg-raw.pt"

# загружаем через PyTorch
data = torch.load(pt_path, map_location="cpu")

print("Тип верхнего объекта:", type(data))

# посмотрим header
print("\n----- HEADER -----")
if "header" in data:
    for k, v in data["header"].items():
        print(f"{k}: {v}")

# посмотрим data
print("\n----- DATA -----")
if "data" in data:
    sample_keys = list(data["data"].keys())
    print("Количество сэмплов:", len(sample_keys))
    print("Пример ключей:", sample_keys[:5])  # первые 5 ключей

    # берём первый сэмпл
    first_key = sample_keys[0]
    print("\nПервый ключ:", first_key)

    sample = data["data"][first_key]

    # показываем, что внутри (обычно mean / std)
    for stat_name, tensor in sample.items():
        if torch.is_tensor(tensor):
            print(f"{stat_name}: тензор формы {tensor.shape}")
            # первые 10 чисел для наглядности
            print("  первые значения:", tensor[:10])
        else:
            print(f"{stat_name}: {type(tensor)}")
# Out:
# Тип верхнего объекта: <class 'dict'>
#
# ----- HEADER -----
# mod: body
# extractor_fp: vitv:google/vit-base-patch16-224:frame-cls
# avg: raw
# frames: 30
# pre_v: v1-stable
#
# ----- DATA -----
# Количество сэмплов: 10
# Пример ключей: ['N4Vfr3zdpGU_001', 'N4Vfr3zdpGU_002', 'N4Vfr3zdpGU_003', 'N4Vfr3zdpGU_004', 'N4Vfr3zdpGU_005']
#
# Первый ключ: N4Vfr3zdpGU_001
# seq: тензор формы torch.Size([30, 768])
#   первые значения: tensor([[-0.0695,  0.9832, -1.0524,  ..., -0.3384, -0.3666, -0.1137],
#         [-0.5894,  1.1313, -0.5859,  ..., -0.1467,  0.1887, -1.1415],
#         [-0.0523, -0.1511, -1.5967,  ..., -0.1761,  0.2489, -1.1777],
#         ...,
#         [-0.6207,  0.1238, -1.4919,  ...,  0.5414,  0.1681, -1.1052],
#         [ 0.2258,  1.0949,  0.1575,  ..., -0.3301, -0.4459, -0.5316],
#         [ 0.1252,  0.5600, -0.0789,  ..., -0.7104, -0.1690,  0.3719]])

# %%
import torch

# путь к твоему файлу .pt
pt_path = r"C:/Prgrm/BDCC_2025/features/wsm_depression/train/body/body__clipv-openai-clip-vit-base-patch32-frame-cls__frames30__avg-raw__pv-v1-stable/feats_seed42_subset10_avg-raw.pt"

# загружаем через PyTorch
data = torch.load(pt_path, map_location="cpu")

print("Тип верхнего объекта:", type(data))

# посмотрим header
print("\n----- HEADER -----")
if "header" in data:
    for k, v in data["header"].items():
        print(f"{k}: {v}")

# посмотрим data
print("\n----- DATA -----")
if "data" in data:
    sample_keys = list(data["data"].keys())
    print("Количество сэмплов:", len(sample_keys))
    print("Пример ключей:", sample_keys[:5])  # первые 5 ключей

    # берём первый сэмпл
    first_key = sample_keys[0]
    print("\nПервый ключ:", first_key)

    sample = data["data"][first_key]

    # показываем, что внутри (обычно mean / std)
    for stat_name, tensor in sample.items():
        if torch.is_tensor(tensor):
            print(f"{stat_name}: тензор формы {tensor.shape}")
            # первые 10 чисел для наглядности
            print("  первые значения:", tensor[:10])
        else:
            print(f"{stat_name}: {type(tensor)}")
# Out:
# Тип верхнего объекта: <class 'dict'>
#
# ----- HEADER -----
# mod: body
# extractor_fp: clipv:openai/clip-vit-base-patch32:frame-cls
# avg: raw
# frames: 30
# pre_v: v1-stable
#
# ----- DATA -----
# Количество сэмплов: 10
# Пример ключей: ['N4Vfr3zdpGU_001', 'N4Vfr3zdpGU_002', 'N4Vfr3zdpGU_003', 'N4Vfr3zdpGU_004', 'N4Vfr3zdpGU_005']
#
# Первый ключ: N4Vfr3zdpGU_001
# seq: тензор формы torch.Size([30, 768])
#   первые значения: tensor([[-1.9902e-01,  4.5787e-01, -1.7409e-01,  ...,  3.9569e-02,
#           2.1914e-01,  5.3384e-02],
#         [-2.9103e-04,  4.3544e-01, -1.6768e-01,  ...,  1.0206e-01,
#           2.3473e-01,  7.6833e-02],
#         [-2.5660e-01,  3.6095e-02,  4.4494e-02,  ..., -2.7317e-02,
#           3.3069e-01,  1.9861e-01],
#         ...,
#         [-3.8549e-02,  3.2639e-01, -2.0136e-01,  ...,  5.8917e-02,
#           1.5093e-01,  1.9805e-02],
#         [-2.2385e-01,  3.9112e-01,  2.5875e-03,  ...,  2.6630e-01,
#           1.4935e-01,  2.8076e-02],
#         [ 1.7708e-01,  3.2305e-01, -1.7196e-01,  ...,  1.9901e-01,
#           1.2944e-01, -4.3854e-01]])

# %%
import torch

# путь к твоему файлу .pt
pt_path = r"C:/Prgrm/BDCC_2025/features/wsm_depression/train/body/body__clipv-openai-clip-vit-base-patch32-frame-mean__frames30__avg-raw__pv-v1-stable/feats_seed42_subset10_avg-raw.pt"

# загружаем через PyTorch
data = torch.load(pt_path, map_location="cpu")

print("Тип верхнего объекта:", type(data))

# посмотрим header
print("\n----- HEADER -----")
if "header" in data:
    for k, v in data["header"].items():
        print(f"{k}: {v}")

# посмотрим data
print("\n----- DATA -----")
if "data" in data:
    sample_keys = list(data["data"].keys())
    print("Количество сэмплов:", len(sample_keys))
    print("Пример ключей:", sample_keys[:5])  # первые 5 ключей

    # берём первый сэмпл
    first_key = sample_keys[0]
    print("\nПервый ключ:", first_key)

    sample = data["data"][first_key]

    # показываем, что внутри (обычно mean / std)
    for stat_name, tensor in sample.items():
        if torch.is_tensor(tensor):
            print(f"{stat_name}: тензор формы {tensor.shape}")
            # первые 10 чисел для наглядности
            print("  первые значения:", tensor[:10])
        else:
            print(f"{stat_name}: {type(tensor)}")
# Out:
# Тип верхнего объекта: <class 'dict'>
#
# ----- HEADER -----
# mod: body
# extractor_fp: clipv:openai/clip-vit-base-patch32:frame-mean
# avg: raw
# frames: 30
# pre_v: v1-stable
#
# ----- DATA -----
# Количество сэмплов: 10
# Пример ключей: ['N4Vfr3zdpGU_001', 'N4Vfr3zdpGU_002', 'N4Vfr3zdpGU_003', 'N4Vfr3zdpGU_004', 'N4Vfr3zdpGU_005']
#
# Первый ключ: N4Vfr3zdpGU_001
# seq: тензор формы torch.Size([30, 768])
#   первые значения: tensor([[ 0.4097,  0.4168,  0.0639,  ...,  0.6023,  0.3559,  0.1365],
#         [ 0.3851,  0.4214,  0.1637,  ...,  0.7338,  0.2703,  0.0843],
#         [ 0.2880,  0.2398,  0.1179,  ...,  0.5152,  0.3414, -0.0136],
#         ...,
#         [ 0.2015,  0.2745,  0.1958,  ...,  0.6290,  0.2622,  0.0693],
#         [ 0.4381,  0.5221,  0.0422,  ...,  0.5073,  0.1556,  0.0800],
#         [ 0.3569,  0.3716, -0.1254,  ...,  0.5189,  0.2434,  0.1372]])

# %%
import torch

# путь к твоему файлу .pt
pt_path = r"C:/Prgrm/BDCC_2025/features/wsm_depression/train/body/body__clipv-openai-clip-vit-base-patch32-tokens__frames30__avg-raw__pv-v1-stable/feats_seed42_subset10_avg-raw.pt"

# загружаем через PyTorch
data = torch.load(pt_path, map_location="cpu")

print("Тип верхнего объекта:", type(data))

# посмотрим header
print("\n----- HEADER -----")
if "header" in data:
    for k, v in data["header"].items():
        print(f"{k}: {v}")

# посмотрим data
print("\n----- DATA -----")
if "data" in data:
    sample_keys = list(data["data"].keys())
    print("Количество сэмплов:", len(sample_keys))
    print("Пример ключей:", sample_keys[:5])  # первые 5 ключей

    # берём первый сэмпл
    first_key = sample_keys[0]
    print("\nПервый ключ:", first_key)

    sample = data["data"][first_key]

    # показываем, что внутри (обычно mean / std)
    for stat_name, tensor in sample.items():
        if torch.is_tensor(tensor):
            print(f"{stat_name}: тензор формы {tensor.shape}")
            # первые 10 чисел для наглядности
            print("  первые значения:", tensor[:10])
        else:
            print(f"{stat_name}: {type(tensor)}")
# Out:
# Тип верхнего объекта: <class 'dict'>
#
# ----- HEADER -----
# mod: body
# extractor_fp: clipv:openai/clip-vit-base-patch32:tokens
# avg: raw
# frames: 30
# pre_v: v1-stable
#
# ----- DATA -----
# Количество сэмплов: 10
# Пример ключей: ['N4Vfr3zdpGU_001', 'N4Vfr3zdpGU_002', 'N4Vfr3zdpGU_003', 'N4Vfr3zdpGU_004', 'N4Vfr3zdpGU_005']
#
# Первый ключ: N4Vfr3zdpGU_001
# seq: тензор формы torch.Size([1470, 768])
#   первые значения: tensor([[ 0.1174, -0.1470,  0.3824,  ...,  0.0484,  0.1930,  0.6511],
#         [ 0.1770, -0.1175,  0.2233,  ...,  0.6919,  0.3201, -0.7050],
#         [-0.0899,  0.3638,  0.0429,  ...,  0.6675,  0.3575, -0.1513],
#         ...,
#         [-0.0419, -0.0498,  0.2046,  ...,  0.9765, -0.2862, -0.1166],
#         [-0.1221,  0.0774,  0.0212,  ...,  0.6461, -0.4347, -0.3962],
#         [ 0.6675,  0.3573,  0.3941,  ...,  0.8563,  0.4982, -0.1876]])
